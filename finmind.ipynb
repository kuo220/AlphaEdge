# %%
import requests
from FinMind.data import DataLoader

# %%
token: str = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyNi0wMS0yNSAwNjoxNDowNSIsInVzZXJfaWQiOiJrdW8yMjAiLCJlbWFpbCI6ImswOTc4MzM3Mjk2QGdtYWlsLmNvbSIsImlwIjoiNjguMTc0LjQ5LjczIn0.5Gbka1hMHqD1yF-dvVGPv3TyTdt4-oH0GrJiPDRXBeo"

api = DataLoader()
api.login_by_token(api_token=token)

# %%
df = api.taiwan_stock_info()

# %%
# from FinMind.data import FinMindApi

# api = FinMindApi()
# api.login_by_token(token)
# print(api.api_usage_limit)

# %%
df = api.taiwan_stock_info()
