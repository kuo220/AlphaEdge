# %%
from utils.db_utils import Data

# %%
data = Data()
# Out:
# /Users/kuofuyu/Desktop/program_project/AlphaEdge/trader/src/utils/db_utils/data.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = (pd.read_sql(s1, self.conn)
# /Users/kuofuyu/Desktop/program_project/AlphaEdge/trader/src/utils/db_utils/data.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = (pd.read_sql(s1, self.conn)

# %%
data.get('price', '收盤價', 10)
# Out:
# stock_id      0050   0051    0052    0053   0055   0056    0057   0061  \
# date
# 2024-09-18  177.85  79.25  173.20   94.85  28.61  37.72  130.90  15.97
# 2024-09-19  180.15  80.60  175.95   96.45  28.99  37.97  132.90  16.20
# 2024-09-20  182.45  80.35  177.80   97.75  29.04  38.15  135.10  16.11
# 2024-09-23  183.25  80.70  178.60   97.90  29.23  38.25  135.05  16.32
# 2024-09-24  185.00  80.80  180.30   99.05  29.30  38.24  135.60  16.76
# 2024-09-25  187.75  81.75  183.50  100.55  29.50  38.73  138.15  17.38
# 2024-09-26  189.30  82.00  185.05  101.45  29.62  38.75  139.55  17.65
# 2024-09-27  188.90  82.65  184.40  101.60  29.43  39.01  139.80  19.04
# 2024-09-30  183.95  81.60  177.10   97.60  29.35  38.66  134.50  22.80
# 2024-10-01  183.60  81.60  179.05   98.70  29.25  38.57  136.25  21.17
#
# stock_id    006201  006203  ...   9944   9945   9946   9949   9950  9951  \
# date                        ...
# ...
